# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     111 # cbook must import matplotlib only within function
#     112 # definitions, so it is safe to import from it here.
# --> 113 from . import _api, _version, cbook, _docstring, rcsetup
#     114 from matplotlib.cbook import sanitize_sequence
#     115 from matplotlib._api import MatplotlibDeprecationWarning
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_docstring.py in <module>
#       1 import inspect
#       2
# ----> 3 from . import _api
#       4
#       5
#
# ImportError: cannot import name '_api' from partially initialized module 'matplotlib' (most likely due to a circular import) (c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
import Projet_Code
from importlib import reload
reload(Projet_Code)
essai_chessboard = Projet_Code.Chessboard(8,5,3,2,4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f53dd162ef92> in <module>
# ----> 1 import Projet_Code
#       2 from importlib import reload
#       3 reload(Projet_Code)
#       4 essai_chessboard = Projet_Code.Chessboard(8,5,3,2,4)
#
# c:\Users\nun-o\Documents\Cours\X\3A\PHY prjet\phy571-qmc-algorithm-for-spin-system\Projet_Code.py in <module>
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from matplotlib import collections  as mc
#       4 from random import *
#       5 from square import Square
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     111 # cbook must import matplotlib only within function
#     112 # definitions, so it is safe to import from it here.
# --> 113 from . import _api, _version, cbook, _docstring, rcsetup
#     114 from matplotlib.cbook import sanitize_sequence
#     115 from matplotlib._api import MatplotlibDeprecationWarning
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_docstring.py in <module>
#       1 import inspect
#       2
# ----> 3 from . import _api
#       4
#       5
#
# ImportError: cannot import name '_api' from partially initialized module 'matplotlib' (most likely due to a circular import) (c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
essai_chessboard._plot_chessboard_image()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4cf8c230b2e6> in <module>
# ----> 1 essai_chessboard._plot_chessboard_image()
#
# NameError: name 'essai_chessboard' is not defined

# %%
for i in range(50): 
    if essai_chessboard.local_update(): essai_chessboard._plot_chessboard_image()
