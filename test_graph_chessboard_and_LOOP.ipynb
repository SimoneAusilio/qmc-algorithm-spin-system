# %%
import Projet_Code
import graph_chessboard
from importlib import reload
reload(graph_chessboard)
chess = Projet_Code.Chessboard(6,20,4,3,3)
chess_graph = graph_chessboard.Graph_chessboard(chess)
# Out:
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107
# W1: 38439.971641211814
# W2: 21.26053449638256
# w3: 0.023517745856009107

# %%
for i in range(10):
    vertex.loop(chess)
# Out:
# loop done
# loop done
# loop done
# loop done
# loop done
# loop done
# loop done
# loop done
# loop done
# loop done

# %%
chess._plot_chessboard_image()
chess_graph._update_graph_chessboard(chess)
chess_graph._plot_graph_chessboard(chess)

# %%
loops = chess_graph._get_loops2(chess)
# Out:
# we are entering in the  1 0 boucle
# 1 0 is not in already in a loop
# looking in square 1 0 arrow 0 0
# vertex de  1 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 0 with arrow 0 1
# looking in square 1 0 arrow 0 1
# vertex de  1 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  0 1 with arrow 1 0
# adding last coodinates to local loop
# [(1, 0), (1, 1)]
# looking in square 0 1 arrow 1 0
# vertex de  0 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  0 1 with arrow 1 1
# looking in square 0 1 arrow 1 1
# vertex de  0 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  1 2 with arrow 0 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2)]
# looking in square 1 2 arrow 0 0
# vertex de  1 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 2 with arrow 0 1
# looking in square 1 2 arrow 0 1
# vertex de  1 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  0 3 with arrow 1 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3)]
# looking in square 0 3 arrow 1 0
# vertex de  0 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  0 3 with arrow 0 0
# looking in square 0 3 arrow 0 0
# vertex de  0 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  7 2 with arrow 1 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3)]
# looking in square 7 2 arrow 1 1
# vertex de  7 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 2 with arrow 0 1
# looking in square 7 2 arrow 0 1
# vertex de  7 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  6 3 with arrow 1 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3)]
# looking in square 6 3 arrow 1 0
# vertex de  6 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  6 3 with arrow 0 0
# looking in square 6 3 arrow 0 0
# vertex de  6 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  5 2 with arrow 1 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3)]
# looking in square 5 2 arrow 1 1
# vertex de  5 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  5 2 with arrow 1 0
# looking in square 5 2 arrow 1 0
# vertex de  5 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  6 1 with arrow 0 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2)]
# looking in square 6 1 arrow 0 1
# vertex de  6 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  6 1 with arrow 0 0
# looking in square 6 1 arrow 0 0
# vertex de  6 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  5 0 with arrow 1 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1)]
# looking in square 5 0 arrow 1 1
# vertex de  5 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  5 0 with arrow 0 1
# looking in square 5 0 arrow 0 1
# vertex de  5 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  4 1 with arrow 1 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1)]
# looking in square 4 1 arrow 1 0
# vertex de  4 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 1 with arrow 0 0
# looking in square 4 1 arrow 0 0
# vertex de  4 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  3 0 with arrow 1 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1)]
# looking in square 3 0 arrow 1 1
# vertex de  3 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  3 0 with arrow 1 0
# looking in square 3 0 arrow 1 0
# vertex de  3 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  4 5 with arrow 0 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6)]
# looking in square 4 5 arrow 0 1
# vertex de  4 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 5 with arrow 1 1
# looking in square 4 5 arrow 1 1
# vertex de  4 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  5 0 with arrow 0 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0)]
# looking in square 5 0 arrow 0 0
# vertex de  5 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  5 0 with arrow 1 0
# looking in square 5 0 arrow 1 0
# vertex de  5 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  6 5 with arrow 0 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6)]
# looking in square 6 5 arrow 0 1
# vertex de  6 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  6 5 with arrow 1 1
# looking in square 6 5 arrow 1 1
# vertex de  6 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  7 0 with arrow 0 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0)]
# looking in square 7 0 arrow 0 0
# vertex de  7 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 0 with arrow 1 0
# looking in square 7 0 arrow 1 0
# vertex de  7 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  0 5 with arrow 0 1
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6)]
# looking in square 0 5 arrow 0 1
# vertex de  0 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  0 5 with arrow 1 1
# looking in square 0 5 arrow 1 1
# vertex de  0 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  1 0 with arrow 0 0
# adding last coodinates to local loop
# [(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)]
# looking in square 1 0 arrow 0 0
# vertex de  1 0 :  [[ 1 -1]
#  [-1  1]]
# coordinates 1 0 already find,end of the loop
# end of the local loop
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)]]
# we are entering in the  3 0 boucle
# 3 0 is not in already in a loop
# looking in square 3 0 arrow 0 0
# vertex de  3 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  3 0 with arrow 0 1
# looking in square 3 0 arrow 0 1
# vertex de  3 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  2 1 with arrow 1 0
# adding last coodinates to local loop
# [(3, 0), (3, 1)]
# looking in square 2 1 arrow 1 0
# vertex de  2 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  2 1 with arrow 1 1
# looking in square 2 1 arrow 1 1
# vertex de  2 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  3 2 with arrow 0 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2)]
# looking in square 3 2 arrow 0 0
# vertex de  3 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  3 2 with arrow 0 1
# looking in square 3 2 arrow 0 1
# vertex de  3 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  2 3 with arrow 1 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3)]
# looking in square 2 3 arrow 1 0
# vertex de  2 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  2 3 with arrow 0 0
# looking in square 2 3 arrow 0 0
# vertex de  2 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  1 2 with arrow 1 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3)]
# looking in square 1 2 arrow 1 1
# vertex de  1 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 2 with arrow 1 0
# looking in square 1 2 arrow 1 0
# vertex de  1 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  2 1 with arrow 0 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2)]
# looking in square 2 1 arrow 0 1
# vertex de  2 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  2 1 with arrow 0 0
# looking in square 2 1 arrow 0 0
# vertex de  2 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  1 0 with arrow 1 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1)]
# looking in square 1 0 arrow 1 1
# vertex de  1 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 0 with arrow 1 0
# looking in square 1 0 arrow 1 0
# vertex de  1 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  2 5 with arrow 0 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6)]
# looking in square 2 5 arrow 0 1
# vertex de  2 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  2 5 with arrow 0 0
# looking in square 2 5 arrow 0 0
# vertex de  2 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  1 4 with arrow 1 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5)]
# looking in square 1 4 arrow 1 1
# vertex de  1 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 4 with arrow 1 0
# looking in square 1 4 arrow 1 0
# vertex de  1 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  2 3 with arrow 0 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4)]
# looking in square 2 3 arrow 0 1
# vertex de  2 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  2 3 with arrow 1 1
# looking in square 2 3 arrow 1 1
# vertex de  2 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  3 4 with arrow 0 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4)]
# looking in square 3 4 arrow 0 0
# vertex de  3 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  3 4 with arrow 1 0
# looking in square 3 4 arrow 1 0
# vertex de  3 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  4 3 with arrow 0 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4)]
# looking in square 4 3 arrow 0 1
# vertex de  4 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 3 with arrow 1 1
# looking in square 4 3 arrow 1 1
# vertex de  4 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  5 4 with arrow 0 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4)]
# looking in square 5 4 arrow 0 0
# vertex de  5 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  5 4 with arrow 0 1
# looking in square 5 4 arrow 0 1
# vertex de  5 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  4 5 with arrow 1 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5)]
# looking in square 4 5 arrow 1 0
# vertex de  4 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 5 with arrow 0 0
# looking in square 4 5 arrow 0 0
# vertex de  4 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  3 4 with arrow 1 1
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5)]
# looking in square 3 4 arrow 1 1
# vertex de  3 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  3 4 with arrow 0 1
# looking in square 3 4 arrow 0 1
# vertex de  3 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  2 5 with arrow 1 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5)]
# looking in square 2 5 arrow 1 0
# vertex de  2 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  2 5 with arrow 1 1
# looking in square 2 5 arrow 1 1
# vertex de  2 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  3 0 with arrow 0 0
# adding last coodinates to local loop
# [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)]
# looking in square 3 0 arrow 0 0
# vertex de  3 0 :  [[ 1 -1]
#  [-1  1]]
# coordinates 3 0 already find,end of the loop
# end of the local loop
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)], [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)]]
# we are entering in the  5 0 boucle
# we are entering in the  7 0 boucle
# we are entering in the  2 1 boucle
# we are entering in the  4 1 boucle
# we are entering in the  6 1 boucle
# we are entering in the  1 2 boucle
# we are entering in the  3 2 boucle
# we are entering in the  5 2 boucle
# 5 2 is not in already in a loop
# looking in square 5 2 arrow 0 0
# vertex de  5 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  5 2 with arrow 0 1
# looking in square 5 2 arrow 0 1
# vertex de  5 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  4 3 with arrow 1 0
# adding last coodinates to local loop
# [(5, 2), (5, 3)]
# looking in square 4 3 arrow 1 0
# vertex de  4 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 3 with arrow 0 0
# looking in square 4 3 arrow 0 0
# vertex de  4 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  3 2 with arrow 1 1
# adding last coodinates to local loop
# [(5, 2), (5, 3), (4, 3)]
# looking in square 3 2 arrow 1 1
# vertex de  3 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  3 2 with arrow 1 0
# looking in square 3 2 arrow 1 0
# vertex de  3 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  4 1 with arrow 0 1
# adding last coodinates to local loop
# [(5, 2), (5, 3), (4, 3), (4, 2)]
# looking in square 4 1 arrow 0 1
# vertex de  4 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  4 1 with arrow 1 1
# looking in square 4 1 arrow 1 1
# vertex de  4 1 :  [[-1  1]
#  [ 1 -1]]
# coordinates 5 2 already find,end of the loop
# end of the local loop
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)], [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)], [(5, 2), (5, 3), (4, 3), (4, 2)]]
# we are entering in the  7 2 boucle
# 7 2 is not in already in a loop
# looking in square 7 2 arrow 0 0
# vertex de  7 2 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 2 with arrow 1 0
# looking in square 7 2 arrow 1 0
# vertex de  7 2 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  0 1 with arrow 0 1
# adding last coodinates to local loop
# [(7, 2), (0, 2)]
# looking in square 0 1 arrow 0 1
# vertex de  0 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  0 1 with arrow 0 0
# looking in square 0 1 arrow 0 0
# vertex de  0 1 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  7 0 with arrow 1 1
# adding last coodinates to local loop
# [(7, 2), (0, 2), (8, 1)]
# looking in square 7 0 arrow 1 1
# vertex de  7 0 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 0 with arrow 0 1
# looking in square 7 0 arrow 0 1
# vertex de  7 0 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  6 1 with arrow 1 0
# adding last coodinates to local loop
# [(7, 2), (0, 2), (8, 1), (7, 1)]
# looking in square 6 1 arrow 1 0
# vertex de  6 1 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 2
# new square:  6 1 with arrow 1 1
# looking in square 6 1 arrow 1 1
# vertex de  6 1 :  [[-1  1]
#  [ 1 -1]]
# coordinates 7 2 already find,end of the loop
# end of the local loop
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)], [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)], [(5, 2), (5, 3), (4, 3), (4, 2)], [(7, 2), (0, 2), (8, 1), (7, 1)]]
# we are entering in the  2 3 boucle
# we are entering in the  4 3 boucle
# we are entering in the  6 3 boucle
# we are entering in the  1 4 boucle
# 1 4 is not in already in a loop
# looking in square 1 4 arrow 0 0
# vertex de  1 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  1 4 with arrow 0 1
# looking in square 1 4 arrow 0 1
# vertex de  1 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  0 5 with arrow 1 0
# adding last coodinates to local loop
# [(1, 4), (1, 5)]
# looking in square 0 5 arrow 1 0
# vertex de  0 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  0 5 with arrow 0 0
# looking in square 0 5 arrow 0 0
# vertex de  0 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  7 4 with arrow 1 1
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5)]
# looking in square 7 4 arrow 1 1
# vertex de  7 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 4 with arrow 0 1
# looking in square 7 4 arrow 0 1
# vertex de  7 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok1
# new square:  6 5 with arrow 1 0
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5), (7, 5)]
# looking in square 6 5 arrow 1 0
# vertex de  6 5 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  6 5 with arrow 0 0
# looking in square 6 5 arrow 0 0
# vertex de  6 5 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok1
# new square:  5 4 with arrow 1 1
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5)]
# looking in square 5 4 arrow 1 1
# vertex de  5 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 2
# new square:  5 4 with arrow 1 0
# looking in square 5 4 arrow 1 0
# vertex de  5 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  6 3 with arrow 0 1
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5), (6, 4)]
# looking in square 6 3 arrow 0 1
# vertex de  6 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  6 3 with arrow 1 1
# looking in square 6 3 arrow 1 1
# vertex de  6 3 :  [[-1  1]
#  [ 1 -1]]
# outward arrow
# ok2
# new square:  7 4 with arrow 0 0
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5), (6, 4), (7, 4)]
# looking in square 7 4 arrow 0 0
# vertex de  7 4 :  [[ 1 -1]
#  [-1  1]]
# inward arrow
# 1
# new square:  7 4 with arrow 1 0
# looking in square 7 4 arrow 1 0
# vertex de  7 4 :  [[ 1 -1]
#  [-1  1]]
# outward arrow
# ok2
# new square:  0 3 with arrow 0 1
# adding last coodinates to local loop
# [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5), (6, 4), (7, 4), (0, 4)]
# looking in square 0 3 arrow 0 1
# vertex de  0 3 :  [[-1  1]
#  [ 1 -1]]
# inward arrow
# 1
# new square:  0 3 with arrow 1 1
# looking in square 0 3 arrow 1 1
# vertex de  0 3 :  [[-1  1]
#  [ 1 -1]]
# coordinates 1 4 already find,end of the loop
# end of the local loop
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)], [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)], [(5, 2), (5, 3), (4, 3), (4, 2)], [(7, 2), (0, 2), (8, 1), (7, 1)], [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5), (6, 4), (7, 4), (0, 4)]]
# we are entering in the  3 4 boucle
# we are entering in the  5 4 boucle
# we are entering in the  7 4 boucle
# we are entering in the  2 5 boucle
# we are entering in the  4 5 boucle
# we are entering in the  6 5 boucle
# loop done

# %%
print(loops)
print(len(loops))
# Out:
# [[(1, 0), (1, 1), (1, 2), (1, 3), (8, 3), (7, 3), (6, 3), (6, 2), (6, 1), (5, 1), (4, 1), (4, 6), (5, 0), (6, 6), (7, 0), (0, 6), (1, 0)], [(3, 0), (3, 1), (3, 2), (3, 3), (2, 3), (2, 2), (2, 1), (2, 6), (2, 5), (2, 4), (3, 4), (4, 4), (5, 4), (5, 5), (4, 5), (3, 5), (3, 0)], [(5, 2), (5, 3), (4, 3), (4, 2)], [(7, 2), (0, 2), (8, 1), (7, 1)], [(1, 4), (1, 5), (8, 5), (7, 5), (6, 5), (6, 4), (7, 4), (0, 4)]]
# 5

# %%
import weights
reload(weights)
a = weights.prob(5,4,1,3,3)
b = weights.prob(1,1,1,3,3)
c = weights.prob(3,2,1,3,3)
print(a,b,c)
# Out:
# W1: 4.9800511945497705
# W2: 1.005800396025405
# w3: 0.4723665527410147
# W1: 4.9800511945497705
# W2: 1.005800396025405
# w3: 0.4723665527410147
# W1: 4.9800511945497705
# W2: 1.005800396025405
# w3: 0.4723665527410147
# -3.7067445032495088 0.4464429357806415 2.740844535169033
